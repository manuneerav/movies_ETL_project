# %%
import requests
import json
import pandas as pd
import sqlalchemy

# %%
#response=requests.get('https://www.reddit.com/r/Wallstreetbets/top.json?limit=1&t=year',verify=False)
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=15cd0ed1d70c32d66d4f4286cca42cb7&language=en-US&page=1',verify=False)
# Out:
# C:\Users\GW651ZK\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
print(response.status_code)
# Out:
# 200

# %%
#d1 = json.loads(response.text)
#or
d1 = response.json()['results']
d1
# Out:
# [{'adult': False,
#   'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
#   'original_title': 'The Godfather',
#   'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#   'popularity': 104.313,
#   'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#   'release_date': '1972-03-14',
#   'title': 'The Godfather',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 17370},
#  {'adult': False,
#   'backdrop_path': '/wPU78OPN4BYEgWYdXyg0phMee64.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
# ...

# %%
df = pd.DataFrame(d1)

# %%
df[['id','title','overview','release_date','popularity','vote_average','vote_count']]
# Out:
#         id                                          title  \
# 0      238                                  The Godfather
# 1      278                       The Shawshank Redemption
# 2      240                          The Godfather Part II
# 3   315162                   Puss in Boots: The Last Wish
# 4      424                               Schindler's List
# 5    19404                    Dilwale Dulhania Le Jayenge
# 6      129                                  Spirited Away
# 7      389                                   12 Angry Men
# 8   372058                                     Your Name.
# 9   496243                                       Parasite
# 10     497                                 The Green Mile
# 11     155                                The Dark Knight
# 12     680                                   Pulp Fiction
# 13     429                 The Good, the Bad and the Ugly
# 14      13                                   Forrest Gump
# ...

# %%
new_df = pd.DataFrame()

# %%
for i in range(1,538):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=15cd0ed1d70c32d66d4f4286cca42cb7&language=en-US&page={}'.format(i),verify=False)
    d = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    new_df = new_df.append(d,ignore_index=True)
# Out:
# C:\Users\GW651ZK\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\GW651ZK\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\GW651ZK\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ...

# %%
new_df.to_csv('movies.csv')

# %%
new_df
# Out:
#           id                         title  \
# 0        238                 The Godfather
# 1        278      The Shawshank Redemption
# 2        240         The Godfather Part II
# 3     315162  Puss in Boots: The Last Wish
# 4        424              Schindler's List
# ...      ...                           ...
# 9995    8427                         I Spy
# 9996    9278                      Freejack
# 9997  125509      Wrong Turn 5: Bloodlines
# 9998   11026       Exorcist: The Beginning
# 9999  373569                      Snatched
#
#                                                overview release_date  \
# 0     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1     Framed in the 1940s for the double murder of h...   1994-09-23
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     Puss in Boots discovers that his passion for a...   2022-12-07
# 4     The true story of how businessman Oskar Schind...   1993-12-15
# ...

# %%
df = pd.read_csv('movies.csv')

# %%
df.head()
# Out:
#    Unnamed: 0      id                         title  \
# 0           0     238                 The Godfather
# 1           1     278      The Shawshank Redemption
# 2           2     240         The Godfather Part II
# 3           3  315162  Puss in Boots: The Last Wish
# 4           4     424              Schindler's List
#
#                                             overview release_date  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     104.313
# 1  Framed in the 1940s for the double murder of h...   1994-09-23     109.584
# 2  In the continuing saga of the Corleone crime f...   1974-12-20      77.755
# 3  Puss in Boots discovers that his passion for a...   2022-12-07    6660.227
# 4  The true story of how businessman Oskar Schind...   1993-12-15      72.243
#
#    vote_average  vote_count
# 0           8.7       17370
# 1           8.7       23161
# 2           8.6       10515
# 3           8.6        2814
# 4           8.6       13694

# %%
df.head()['vote_count']
# Out:
# 0    17370
# 1    23161
# 2    10515
# 3     2814
# 4    13694
# Name: vote_count, dtype: int64

# %%
engine = sqlalchemy.create_engine("mysql+pymysql://root:Terminator$6@localhost:3306/moviedb")

# %%
df = pd.read_sql_table("new_table",engine)

# %%
df
# Out:
# Empty DataFrame
# Columns: [id, vote_count, vote_average, popularity]
# Index: []

# %%
df = pd.read_csv('movies.csv')
df1 = df[['id','vote_count','vote_average','popularity']]
df1
# Out:
#           id  vote_count  vote_average  popularity
# 0        238       17370           8.7     104.313
# 1        278       23161           8.7     109.584
# 2        240       10515           8.6      77.755
# 3     315162        2814           8.6    6660.227
# 4        424       13694           8.6      72.243
# ...      ...         ...           ...         ...
# 9995    8427         829           5.4      15.102
# 9996    9278         264           5.4      11.213
# 9997  125509         777           5.4      72.449
# 9998   11026         653           5.4      13.937
# 9999  373569         726           5.4      12.876
#
# [10000 rows x 4 columns]

# %%
df1.to_sql(
    name ='new_table',
    con = engine,
    index=False,
    if_exists='append'
    
    
)

# %%
df = pd.read_sql_table("new_table2",engine)
df
# Out:
# Empty DataFrame
# Columns: [id, title, overview, release_date]
# Index: []

# %%
df3 = pd.read_csv('movies.csv')
df_3 = df3[['id','title','release_date']]
df_3
# Out:
#           id                         title release_date
# 0        238                 The Godfather   1972-03-14
# 1        278      The Shawshank Redemption   1994-09-23
# 2        240         The Godfather Part II   1974-12-20
# 3     315162  Puss in Boots: The Last Wish   2022-12-07
# 4        424              Schindler's List   1993-12-15
# ...      ...                           ...          ...
# 9995    8427                         I Spy   2002-10-31
# 9996    9278                      Freejack   1992-01-17
# 9997  125509      Wrong Turn 5: Bloodlines   2012-10-23
# 9998   11026       Exorcist: The Beginning   2004-08-20
# 9999  373569                      Snatched   2017-05-03
#
# [10000 rows x 3 columns]

# %%
df_3['title'] = df_3['title'].astype('string')
#df_3['overview'] = df_3['overview'].astype('string')
df_3['release_date'] = pd.to_datetime(df_3["release_date"])
# Out:
# C:\Users\GW651ZK\AppData\Local\Temp/ipykernel_17464/1320633998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3['title'] = df_3['title'].astype('string')
# C:\Users\GW651ZK\AppData\Local\Temp/ipykernel_17464/1320633998.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3['release_date'] = pd.to_datetime(df_3["release_date"])

# %%
df_3.to_sql(
    name ='new_table2',
    con = engine,
    index=False,
    if_exists='append'
    
    
)

# %%
df_3['title'] = df_3['title'].astype('string')
df_3['overview'] = df_3['overview'].astype('string')
df_3['release_date'] = pd.to_datetime(df_3["release_date"])
# Out:
# C:\Users\GW651ZK\AppData\Local\Temp/ipykernel_17464/2149848745.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3['title'] = df_3['title'].astype('string')
# C:\Users\GW651ZK\AppData\Local\Temp/ipykernel_17464/2149848745.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3['overview'] = df_3['overview'].astype('string')
# C:\Users\GW651ZK\AppData\Local\Temp/ipykernel_17464/2149848745.py:3: SettingWithCopyWarning:
# ...

# %%
df_3['release_date']
# Out:
# 0      1972-03-14
# 1      1994-09-23
# 2      1974-12-20
# 3      2022-12-07
# 4      1993-12-15
#           ...
# 9995   2002-10-31
# 9996   1992-01-17
# 9997   2012-10-23
# 9998   2004-08-20
# 9999   2017-05-03
# Name: release_date, Length: 10000, dtype: datetime64[ns]
